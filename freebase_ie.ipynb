# %%
import json
import urllib
import sys
from collections import defaultdict

# %%
# remove '_' if it is concatenating two words
# remove '_' and append s if it is plural
def sanitize_relation(relation):
    tokens = relation.split('_')
    if tokens[-1] == 's':
        tokens[-2] = tokens[-2] + 's'
        tokens.pop()

    return " ".join(tokens)

def sanitize_compound_arg(arg):
    tokens = arg.split(' - ')
    del tokens[-2:]
    return " ".join(tokens)

# %%
def search_api_request(api_key, query):
    service_url = 'https://www.googleapis.com/freebase/v1/search'
    params = {
        'key': api_key,
        'query': query,
    }
    url = service_url + '?' + urllib.urlencode(params)
    response = json.loads(urllib.urlopen(url).read())
    return response

# %%
def extract_first_result(response):
    first_result = response['result'][0]
    topic_name = str(first_result['name'])
    topic_id = str(first_result['mid']) # To be used by the topic API in scraping relations
    return (topic_name, topic_id)

# %%
def topic_api_request(api_key, topic):
    service_url = 'https://www.googleapis.com/freebase/v1/topic'
    params = {
      'key': api_key,
    }
    topic_id = topic[1]
    url = service_url + topic_id + '?' + urllib.urlencode(params)
    print "URL: " + url
    topic = json.loads(urllib.urlopen(url).read())
    return topic

# %%
def print_tuples(tuples):
    for t in tuples:
        print t[0]
        print "==="
        print t[1]
        print "==="
        print t[2]
        print "\n"

# %%
def construct_ppdb_from_file(file_name):
    ppdb = defaultdict(list)
    count = 0
    with open(file_name) as f:
        for line in f:
            data = line.split(" ||| ")
            pos_tag = data[0]
            source = data[1]
            target = data[2]
            ppdb[source].append(target)
            count += 1
            
    print str(count) + " paraphrases added to PPDB"
    return ppdb


def expand_tuple_for_phrase(t, phrase, ppdb, tuples):
    for paraphrase in ppdb[phrase]:
        t[1].append(paraphrase)

def expand_tuples_with_ppdb(ppdb, tuples):
    
    for t in tuples:
        phrase = t[1][0]
        expand_tuple_for_phrase(t, phrase, ppdb, tuples)
        for sub_phrase in phrase.split(' '):
            expand_tuple_for_phrase(t, sub_phrase, ppdb, tuples)

# %%
def construct_tuples(name, response):
    tuples = []
    if 'property' not in response: 
        return [] 

    for property in response['property']:
        simple_prop = str(property.split('/')[-1])
        simple_prop = sanitize_relation(simple_prop)
        
        for value in response['property'][property]['values']:
            if not value['text']:
                continue 
            arg = value['text'].encode("utf8") 
            if response['property'][property]['valuetype'] == 'compound':
                arg = sanitize_compound_arg(arg)     
           
            tuples.append((name, [simple_prop], str(arg)))
            
    return tuples

# %%
def allow_tuple(tuple):
     
    disallowed_relations = ['key', 'type', 'creator', 'image', 'timestamp', 'guid', 'attribution']
    # If t contains '/' we skip.
    # These are indicative of a Freebase topic-topic link, url, or other meta-data.
    if not tuple[2] or '/' in tuple[2]:
        return False
    if tuple[1][0] in disallowed_relations:
        return False
    if 'notable' in tuple[1][0]:
        return False
    
    return True

def sanitize_tuples(tuples, log_blocked=False):
    allowed_tuples = []
    blocked_tuples = []
    for t in tuples:
        if allow_tuple(t):
            allowed_tuples.append(t)
        else:
            blocked_tuples.append(t)
       
    if (log_blocked):
        print "== Start Blocked Tuples =="
        print_tuples(blocked_tuples)
        print "== End Blocked Tuples == \n"

    return allowed_tuples

# %%
def random_freebase_topic():
    service_url = 'http://en.wikipedia.org/w/api.php'
    params = {
        'action': 'query',
        'format': 'json',
        'list': 'random',
        'rnlimit': '1',
        'rnnamespace': '0'
    }
    url = service_url + '?' + urllib.urlencode(params)
    response = json.loads(urllib.urlopen(url).read())
    title = response['query']['random'][0]['title']
    print title
    
    try:
        encoded_title = urllib.quote_plus(title).replace('+', '_')
    except:
        print "Error parsing title: " + title
        return None
    
    topic_name = title
    topic_id = "/wikipedia/en/" + encoded_title
    return (topic_name, topic_id)

# %%
# query=None defaults to random
# used_ppdb defines whether each relation should be expanded with ppdb
# min_tuples is used when no query is set, topics will be randomly selected until min_tuples is satisfied.
def extract_freebase_tuples(query=None, used_ppdb=False, min_tuples=6, ppdb=None):
    api_key = open(".api_key").read()
    tuples = []
    
    while True:
        
        if query:
            search_result = search_api_request(api_key, query)
            topic = extract_first_result(search_result)
        else:
            topic = random_freebase_topic()
            if not topic:
                continue
            
        response = topic_api_request(api_key, topic)
        tuples = construct_tuples(topic[0], response)
        tuples = sanitize_tuples(tuples, log_blocked=False)
        
        # Only if topics are randomly selected do we continue until min_tuples
        if query or len(tuples) >= min_tuples:
            break
    
    if used_ppdb:
        expand_tuples_with_ppdb(ppdb, tuples)
    
    return tuples

# %%
ppdb = construct_ppdb_from_file("ppdb-1.0-s-all")
# Out:
# 6977679 paraphrases added to PPDB

# %%
# Example query for "Obama" with PPDB turned off
#tuples = extract_freebase_tuples(query="Obama", used_ppdb=False, ppdb=ppdb)

# Example query for "Stanford" with PPDB expansion turned on
tuples = extract_freebase_tuples(query="Google", used_ppdb=True, ppdb=ppdb)

# Example random query, requiring 10 relation tuples (pre-PPDB) 
#tuples = extract_freebase_tuples(query=None, used_ppdb=False, min_tuples=10, ppdb=ppdb)
print tuples[5]
print_tuples(tuples)
# Out:
# URL: https://www.googleapis.com/freebase/v1/topic/m/045c7b?key=AIzaSyCWE0_nON79_obE5cyQHblgzD1ODtm50RQ
# ('Google', ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament'], '2004 John L. Hennessy')
# Google
# ===
# ['awards won', 'awards program', 'stock exchanges', 'the prizes', 'arbitral awards', 'the scholarships', "'ve won", "'s won", "'d won", 'he wins', "'s winning"]
# ===
# Clio Award for Advertiser of the Year 2013 Clio Awards 2013
#
#
# Google
# ===
# ['daylife topic', 'subject matter']
# ===
# 0bgUgbUf0P1N2
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# 2011-04-04 Larry Page Chief Executive Officer CEO and Co-Founder
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# 2001-03 Eric Schmidt Chairman 2011-04-04
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# John Doerr
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# 2004 John L. Hennessy
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Ann Mather
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Paul Otellini
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Ram Shriram
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Shirley M. Tilghman
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Sergey Brin Founder
#
#
# Google
# ===
# ['board members', 'commissioners', 'council', 'council', 'board of referees', 'joint committee', 'executive board', 'governing council', 'board of directors', 'the council', 'executive board', 'board of directors', 'board of directors', 'governing council', 'the council', "council 's", 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# 2011-04-04 Eric Schmidt Executive Chairman Executive Chairman
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Maps API
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# BigTable
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# KHTML
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Shopping
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Picasa
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Earth
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Analytics
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Page Creator
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Finance
#
#
# Google
# ===
# ['software', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications', 'computer software', 'software programs', 'software tools', 'software packages', 'software products', 'computer software', 'computer programs', 'software applications']
# ===
# Google Notebook
#
#
# Google
# ===
# ['sponsorship', 'limited partnership', 'the patronage', 'limited partnership', 'the patronage']
# ===
# OSCON 2009
#
#
# Google
# ===
# ['sponsorship', 'limited partnership', 'the patronage', 'limited partnership', 'the patronage']
# ===
# Google Summer of Code
#
#
# Google
# ===
# ['number of employees', 'document number', 'total number', 'phone number', 'large number', 'the name', '-lrb- d', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 13748 2007-06-30
#
#
# Google
# ===
# ['number of employees', 'document number', 'total number', 'phone number', 'large number', 'the name', '-lrb- d', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 12238 2007-03-31
#
#
# Google
# ===
# ['number of employees', 'document number', 'total number', 'phone number', 'large number', 'the name', '-lrb- d', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 10000 2006
#
#
# Google
# ===
# ['number of employees', 'document number', 'total number', 'phone number', 'large number', 'the name', '-lrb- d', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 24400 2009-01-08
#
#
# Google
# ===
# ['number of employees', 'document number', 'total number', 'phone number', 'large number', 'the name', '-lrb- d', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 34311 2012-06
#
#
# Google
# ===
# ['projects', 'the drafts', 'the draft', 'works projects', 'a project', 'the project', 'the drafts', 'the draft', 'works projects', 'a project', 'the project']
# ===
# Michigan Digitization Project
#
#
# Google
# ===
# ['projects', 'the drafts', 'the draft', 'works projects', 'a project', 'the project', 'the drafts', 'the draft', 'works projects', 'a project', 'the project']
# ===
# Project Loon
#
#
# Google
# ===
# ['projects', 'the drafts', 'the draft', 'works projects', 'a project', 'the project', 'the drafts', 'the draft', 'works projects', 'a project', 'the project']
# ===
# Google Fiber
#
#
# Google
# ===
# ['projects', 'the drafts', 'the draft', 'works projects', 'a project', 'the project', 'the drafts', 'the draft', 'works projects', 'a project', 'the project']
# ===
# Google driverless car
#
#
# Google
# ===
# ['projects', 'the drafts', 'the draft', 'works projects', 'a project', 'the project', 'the drafts', 'the draft', 'works projects', 'a project', 'the project']
# ===
# 2011 Google Glass Host Organization
#
#
# Google
# ===
# ['subjects', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes']
# ===
# Google Apps for Business
#
#
# Google
# ===
# ['subjects', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes']
# ===
# Google Sheets
#
#
# Google
# ===
# ['subjects', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes']
# ===
# Google Slides
#
#
# Google
# ===
# ['subjects', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes']
# ===
# Lino Uruñuela
#
#
# Google
# ===
# ['subjects', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes', 'topics', 'the topics', 'c. subjects', 'subject areas', 'the themes']
# ===
# Google Cloud Platform
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2007 Endoxon ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2009 Postini UK Ltd ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2009 Google Company Google OOO ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2009 MessageMedia GmbH ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2008 PiFidelity Holding Corp ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2006 Applied Semantics ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2009 Scott Concepts, LLC ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2008 Google Bermuda Unlimited ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2009 DoubleClick International Advertising Ltd ts_bot
#
#
# Google
# ===
# ['child', 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's", 'children', "children 's", "child 's", "child 's", 'of children', 'child -lrb- crc -rrb-', "children 's", 'the son', 'child -lrb- crc', 'the children', "the child 's", 'a kid', "the child 's"]
# ===
# 2008 Google Czech Republic s.r.o. ts_bot
#
#
# Google
# ===
# ['brands', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google Apps for Business
#
#
# Google
# ===
# ['brands', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google Drive
#
#
# Google
# ===
# ['brands', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google Cloud Platform
#
#
# Google
# ===
# ['brands', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google Maps
#
#
# Google
# ===
# ['computer models', 'authorising officer', 'computer science', 'information technology', 'role models', 'role models', 'the templates', 'the patterns']
# ===
# Chromebook Pixel
#
#
# Google
# ===
# ['organization type', 'organisation', 'organisation', 'organisation', 'organisation', 'organisation', 'organisation', "organization 's", "organization 's", 'c. organization', 'e. organization', "the organization 's", 'the organisation', 'organisation ,', 'organizations of', 'the united', 'the united', 'organization -lrb- wto -rrb-', 'united nations', 'the organisation', 'organizational structure', 'kind', 'kind', 'please enter', 'please type', 'the kind', 'the guy', 'then type']
# ===
# Public company
#
#
# Google
# ===
# ['liabilities', 'the liability', 'a liability', 'the obligations', 'accrued liabilities', 'the liability', 'a liability', 'the obligations', 'accrued liabilities']
# ===
# 3528710000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Salar Kamangar Vice President of Product Management
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# David Lawee Vice President of Marketing
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Mario Queiroz Vice President, Product Management, EMEA & Latin America
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Lorraine Twohill Vice President, Marketing, EMEA
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Susan Wojcicki Vice President of Product Management
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Daniel Alegre Vice President, Latin America and APLA Business Development
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Tim Armstrong President, Advertising and Commerce, North America, & Vice President, Google Inc. 2009-03
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# 2011-01 Nikesh Arora Senior Vice President 2014-07
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# Sukhinder Singh Cassidy Vice President, Asia-Pacific & Latin America Operations
#
#
# Google
# ===
# ['employees', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff', 'an employee', 'the workers', 'wage earners', 'the employee', 'staff members', 'employed persons', 'the employed', 'public servants', "workers '", 'the staff', "employee 's", 'individual employees', 'working people', 'their staff']
# ===
# David Eun Vice President, Content Partnerships
#
#
# Google
# ===
# ['films', 'movies', 'movies', 'movies', 'film', 'the movies', 'feature films', 'the film', 'your movies', 'the movie', 'movies', 'movies', 'movies', 'film', 'the movies', 'feature films', 'the film', 'your movies', 'the movie']
# ===
# Google and the World Brain
#
#
# Google
# ===
# ['members', 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament', 'member', 'member', 'member', 'member', 'honourable members', 'the honourable', 'members of parliament', 'the membership', 'fellow members', 'a member', 'the honourable members', 'the meps', 'member states', 'member countries', 'the members of parliament']
# ===
# Acxiom Corporation
#
#
# Google
# ===
# ['member of', 'members', 'members', 'members', 'members', 'the members', 'the states', 'a fellow', 'a fellow', '-lrb- d']
# ===
# 2007-11-05 Open Handset Alliance
#
#
# Google
# ===
# ['member of', 'members', 'members', 'members', 'members', 'the members', 'the states', 'a fellow', 'a fellow', '-lrb- d']
# ===
# Interactive Advertising Bureau
#
#
# Google
# ===
# ['member of', 'members', 'members', 'members', 'members', 'the members', 'the states', 'a fellow', 'a fellow', '-lrb- d']
# ===
# Network Advertising Initiative
#
#
# Google
# ===
# ['headquarters', 'the seat', 'head office', 'national headquarters', 'the central administration', 'registered office', 'central administration', 'the headquarters level', 'head office', 'united nations headquarters', 'the head office', 'central government', 'headquarters locations', 'the siege', 'central bureau', 'the seat', 'head office', 'national headquarters', 'the central administration', 'registered office', 'central administration', 'the headquarters level', 'head office', 'united nations headquarters', 'the head office', 'central government', 'headquarters locations', 'the siege', 'central bureau']
# ===
# Location Mountain View United States of America 94043 California 1600 Amphitheatre Parkway
#
#
# Google
# ===
# ['legal structure', 'legal affairs', 'organizational structure']
# ===
# Corporation
#
#
# Google
# ===
# ['legal structure', 'legal affairs', 'organizational structure']
# ===
# Publicly listed company
#
#
# Google
# ===
# ['name', 'behalf', 'behalf', 'behalf of', 'behalf of', 'number of', 'number of', 'first name', 'last name', 'last name', 'given name', 'behalf of the', "'s name", "'s behalf", 'the names', 'fucking name', 'behalf ,', 'name again', 'behalf', 'behalf', 'behalf of', 'behalf of', 'number of', 'number of', 'first name', 'last name', 'last name', 'given name', 'behalf of the', "'s name", "'s behalf", 'the names', 'fucking name', 'behalf ,', 'name again']
# ===
# Google
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# YouTube 2006-11
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# FeedBurner 2007-06-03
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# Postini 2007
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# DoubleClick 2008-03-11
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# JotSpot 2006-10-31
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# Metaweb Technologies, Inc. 2010-07-16
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# AdMob 2009-11
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# ITA Software 2010-07
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# Keyhole, Inc 2004
#
#
# Google
# ===
# ['companies acquired', 'enterprises', 'businesses', 'firms', 'the enterprises', 'the businesses', 'the firms', 'the societies', 'the undertakings', 'business enterprises', 'the corporations', 'a company', 'the company']
# ===
# Pyra Labs 2003
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Daniel Podgaichenko
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Evgeniy Orlov
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Nick Ker
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Kerr Communications
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Google Apps for Business
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# AngularJS
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# DEJAN
#
#
# Google
# ===
# ['subject of', 'subject matter', 'the object', 'subject matter', 'taxable persons', 'the subject matter', 'the purpose', 'the topic', '-lrb- d']
# ===
# Google for Education
#
#
# Google
# ===
# ['phone number', 'telephone number', 'telephone number', 'telephone number', 'telephone number', 'telephone number', 'telephone number', 'telephone number', 'telephone', 'phone', 'number', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'telephone', 'phone number', 'the telephone', 'cell phone', 'tel .', 'a telephone', 'phone calls', 'document number', 'total number', 'phone number', 'large number', 'the name']
# ===
# 1 (650) 253-0000 Mountain View
#
#
# Google
# ===
# ['place founded', 'a seat', 'taking place', 'the spot', 'your site', 'of all', 'be held', 'well founded']
# ===
# Menlo Park
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2007-06-03 FeedBurner
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2004-01-22 Orkut
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2003-02 Blogger
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 1997-09-15 Google Search
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2004-04-01 Gmail
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2012-09-27 Google Trends
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2005-05 iGoogle
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2006-04-13 Google Calendar
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2006-08-31 2011-09-16 Google Image Labeler
#
#
# Google
# ===
# ['websites owned new', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to', 'new ones', 'once again']
# ===
# 2005-10-07 Google Reader
#
#
# Google
# ===
# ['retained earnings', 'being highlighted during focus 2007', 'the gains', 'the remuneration', 'the income']
# ===
# 13561630000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['alias', 'aliases', 'aliases', 'aliases', 'aliases', 'aliases', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'aliases', 'aliases', 'aliases', 'aliases', 'aliases', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'a.k.a.']
# ===
# Google, Inc.
#
#
# Google
# ===
# ['alias', 'aliases', 'aliases', 'aliases', 'aliases', 'aliases', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'aliases', 'aliases', 'aliases', 'aliases', 'aliases', 'a.k.a.', 'a.k.a.', 'a.k.a.', 'a.k.a.']
# ===
# Google Inc
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Apache Wave
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Google Buzz 2010-02 Google Buzz is a Gmail extension that enables users to share updates, photos, videos, and more. Google Buzz Logo Ariel P.
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Nexus One 2010 2010
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Nexus S 2010
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Nexus 7
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Nexus 10
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Google Earth
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Google Maps
#
#
# Google
# ===
# ['products', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce', 'product', 'the outputs', 'the goods', 'the product', 'a product', 'the produce']
# ===
# Chromecast
#
#
# Google
# ===
# ['appears in ranked lists', 'is displayed', 'is displayed', 'will appear', 'would appear', 'would seem', 'is contained', 'is listed', 'will be displayed', 'is shown', 'pops up', 'will display', 'seems to be', '-lrb- v', 'are listed', 'a list', 'the list', 'are displayed']
# ===
# Fortune 100 Best Companies to Work For 4 2009
#
#
# Google
# ===
# ['appears in ranked lists', 'is displayed', 'is displayed', 'will appear', 'would appear', 'would seem', 'is contained', 'is listed', 'will be displayed', 'is shown', 'pops up', 'will display', 'seems to be', '-lrb- v', 'are listed', 'a list', 'the list', 'are displayed']
# ===
# Fortune 1000 117 2009
#
#
# Google
# ===
# ['appears in ranked lists', 'is displayed', 'is displayed', 'will appear', 'would appear', 'would seem', 'is contained', 'is listed', 'will be displayed', 'is shown', 'pops up', 'will display', 'seems to be', '-lrb- v', 'are listed', 'a list', 'the list', 'are displayed']
# ===
# Fortune 1000 150 2008
#
#
# Google
# ===
# ['appears in ranked lists', 'is displayed', 'is displayed', 'will appear', 'would appear', 'would seem', 'is contained', 'is listed', 'will be displayed', 'is shown', 'pops up', 'will display', 'seems to be', '-lrb- v', 'are listed', 'a list', 'the list', 'are displayed']
# ===
# Fortune 1000 353 2006
#
#
# Google
# ===
# ['appears in ranked lists', 'is displayed', 'is displayed', 'will appear', 'would appear', 'would seem', 'is contained', 'is listed', 'will be displayed', 'is shown', 'pops up', 'will display', 'seems to be', '-lrb- v', 'are listed', 'a list', 'the list', 'are displayed']
# ===
# Fortune Global 500 423 2009
#
#
# Google
# ===
# ['assets', 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate', 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate']
# ===
# 72574000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['assets', 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate', 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate']
# ===
# 31767580000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['product lines', 'products', 'of proceeds', 'the proceeds', 'proceeds derived', 'of the proceeds', 'the products', 'the produce', "product 's", 'following product', 'budget lines']
# ===
# 2010-01 Google Nexus
#
#
# Google
# ===
# ['slogan']
# ===
# Don't be evil
#
#
# Google
# ===
# ['organizations founded', 'organisations', 'organisations', 'organisations', 'organisations', 'the organisations', 'organization of', 'well founded']
# ===
# Open Handset Alliance
#
#
# Google
# ===
# ['organizations founded', 'organisations', 'organisations', 'organisations', 'organisations', 'the organisations', 'organization of', 'well founded']
# ===
# Calico
#
#
# Google
# ===
# ['awards presented', 'awards program', 'stock exchanges', 'the prizes', 'arbitral awards', 'the scholarships', 'submitted', 'submitted', 'submitted', 'put forward', 'set forth', 'has submitted', 'been submitted', 'has tabled', 'brought forward']
# ===
# Google O'Reilly Open Source Award
#
#
# Google
# ===
# ['awards presented', 'awards program', 'stock exchanges', 'the prizes', 'arbitral awards', 'the scholarships', 'submitted', 'submitted', 'submitted', 'put forward', 'set forth', 'has submitted', 'been submitted', 'has tabled', 'brought forward']
# ===
# Google Lunar X Prize
#
#
# Google
# ===
# ['description', 'about alternate', 'business description', 'business description', 'issues and narrative', 'record number', 'narrative description', 'product overview', 'product overview', 'role played in', 'about alternate', 'business description', 'business description', 'issues and narrative', 'record number', 'narrative description', 'product overview', 'product overview', 'role played in']
# ===
# Google Inc. (NASDAQ: GOOG) is an American multinational corporation which provides...
#
#
# Google
# ===
# ['description', 'about alternate', 'business description', 'business description', 'issues and narrative', 'record number', 'narrative description', 'product overview', 'product overview', 'role played in', 'about alternate', 'business description', 'business description', 'issues and narrative', 'record number', 'narrative description', 'product overview', 'product overview', 'role played in']
# ===
# Google is a U.S. headquartered, multinational corporation specializing in Internet-related...
#
#
# Google
# ===
# ['founders', 'founding', 'founding']
# ===
# Sergey Brin
#
#
# Google
# ===
# ['founders', 'founding', 'founding']
# ===
# Larry Page
#
#
# Google
# ===
# ['sectors', 'the areas', 'business lines', 'different sectors', 'departments concerned', 'the areas', 'business lines', 'different sectors', 'departments concerned']
# ===
# The Internet
#
#
# Google
# ===
# ['sectors', 'the areas', 'business lines', 'different sectors', 'departments concerned', 'the areas', 'business lines', 'different sectors', 'departments concerned']
# ===
# Software
#
#
# Google
# ===
# ['sectors', 'the areas', 'business lines', 'different sectors', 'departments concerned', 'the areas', 'business lines', 'different sectors', 'departments concerned']
# ===
# Software development
#
#
# Google
# ===
# ['sectors', 'the areas', 'business lines', 'different sectors', 'departments concerned', 'the areas', 'business lines', 'different sectors', 'departments concerned']
# ===
# Telecommunications equipment
#
#
# Google
# ===
# ['operating income', 'to operate', 'revenue', 'revenue', 'the revenue', 'the incomes', 'income tax', 'the revenues', 'their incomes', 'come back', 'the earnings', 'income level']
# ===
# 11742000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['operating income', 'to operate', 'revenue', 'revenue', 'the revenue', 'the incomes', 'income tax', 'the revenues', 'their incomes', 'come back', 'the earnings', 'income level']
# ===
# 4121900000.0 United States Dollar 2006-12-31
#
#
# Google
# ===
# ['net profit', 'net profits', 'net worth', 'a net basis', 'the profits', 'the benefit', 'their profits', 'its profits', 'the benefits']
# ===
# 9737000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['net profit', 'net profits', 'net worth', 'a net basis', 'the profits', 'the benefit', 'their profits', 'its profits', 'the benefits']
# ===
# 4226860000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue']
# ===
# 37905000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue']
# ===
# 29321000000.0 United States Dollar 2010-12-31
#
#
# Google
# ===
# ['revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue']
# ===
# 23651000000.0 United States Dollar 2009-12-31
#
#
# Google
# ===
# ['revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue']
# ===
# 21795550000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue', 'income', 'income', 'revenues', 'the income', 'the revenues', 'income tax', 'the incomes', 'tax revenue', 'government revenue']
# ===
# 10604900000.0 United States Dollar 2006-12-31
#
#
# Google
# ===
# ['party to cases', 'part', 'part', 'part', 'part', "party 's", 'the part', 'a part', 'part of', "the party 's", 'the parties', 'been gone', 'political party', 'in order to', 'in order to', 'in order to', 'in order', 'order to', 'in order', '-lrb- k', '-lrb- d', 'with a view to', 'case', 'the event', 'the case', 'the instances', 'a case', 'case basis', 'the causes', 'those instances', 'the affairs']
# ===
# Author's Guild v. Google Defendant
#
#
# Google
# ===
# ...
# ===
# 2011-11 Ivanpah Solar Power Facility
#
#
# Google
# ===
# ['includes brands', 'consists of', 'shall include', 'consists of', 'shall include', 'is comprised', 'shall comprise', 'are included', 'comes with', 'shall comprise', 'is included', 'is comprised of', 'is inclusive', 'is inclusive of', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google for Work
#
#
# Google
# ===
# ['includes brands', 'consists of', 'shall include', 'consists of', 'shall include', 'is comprised', 'shall comprise', 'are included', 'comes with', 'shall comprise', 'is included', 'is comprised of', 'is inclusive', 'is inclusive of', 'trade marks', 'trade marks', 'brand names', 'the marks', 'brand names', 'punch marks', 'brand name', 'trade mark', 'the markings']
# ===
# Google Apps for Business
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Image Labeler
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Calendar
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Reader
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Shopping
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Code Search
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Maps
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Groups
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Google Developers
#
#
# Google
# ===
# ['websites owned', 'web sites', 'web sites', 'web sites', 'web sites', 'internet sites', 'the web sites', 'web site', 'web pages', 'these web sites', 'belonging to']
# ===
# Freebase
#
#
# Google
# ===
# ['conferences', 'major conferences', 'various conferences', 'major conferences', 'various conferences']
# ===
# FOSDEM
#
#
# Google
# ===
# ['conferences', 'major conferences', 'various conferences', 'major conferences', 'various conferences']
# ===
# PyCon
#
#
# Google
# ===
# ['conferences', 'major conferences', 'various conferences', 'major conferences', 'various conferences']
# ===
# GOTO
#
#
# Google
# ===
# ['conferences', 'major conferences', 'various conferences', 'major conferences', 'various conferences']
# ===
# OSCON 2012
#
#
# Google
# ===
# ['conferences', 'major conferences', 'various conferences', 'major conferences', 'various conferences']
# ===
# O'Reilly Open Source Convention
#
#
# Google
# ===
# ['current liabilities', 'present', 'the present', 'at present', "today 's", 'the liability', 'a liability', 'the obligations', 'accrued liabilities']
# ===
# 8913000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['current liabilities', 'present', 'the present', 'at present', "today 's", 'the liability', 'a liability', 'the obligations', 'accrued liabilities']
# ===
# 2302090000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['date founded', 'this day', 'that day', 'date of entry', 'well founded']
# ===
# 1998-09-04
#
#
# Google
# ===
# ['patents assigned', 'patent', 'a patent', 'the patent', 'the patenting', 'patent rights']
# ===
# US7960945
#
#
# Google
# ===
# ['issue', 'question', 'question', 'question', 'question', 'matter', 'the question', 'a matter', 'a question', 'question', 'question', 'question', 'question', 'matter', 'the question', 'a matter', 'a question']
# ===
# GOOGLE INC-CL A Common Stock
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Technology
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Advertising
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Software
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Search engine
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Search engine
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Geographic information system
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Search Engine Marketing
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Information technology
#
#
# Google
# ===
# ['industry', "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's", "industry 's", "l 'industrie", 'both industry', 'the industrial sector', "the industry 's", 'industry sector', 'industrial sector', 'industry representatives', 'the sector', 'the industries', "industry 's"]
# ===
# Internet Publishing and Broadcasting and Web Search Portal
#
#
# Google
# ===
# ['current assets', 'present', 'the present', 'at present', "today 's", 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate']
# ===
# 52758000000.0 United States Dollar 2011-12-31
#
#
# Google
# ===
# ['current assets', 'present', 'the present', 'at present', "today 's", 'the asset', 'the property', 'an asset', 'the holdings', 'capital assets', 'the goods', 'the estate']
# ===
# 20178180000.0 United States Dollar 2008-12-31
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Chrome OS
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Honeycomb
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Ice Cream Sandwich
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Key Lime Pie
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Jelly Bean
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Android
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Goobuntu
#
#
# Google
# ===
# ['operating systems developed', 'to operate', 'developed countries', 'drawn up', 'developed countries', 'worked out', 'the developed countries', 'further developed', 'developed further']
# ===
# Android Lollipop
#
#
# Google
# ===
# ['partnerships', 'building partnerships', 'partnership building', 'the partnership', 'partnership development', 'collaborative relationships', 'the associations', 'c. partnerships', 'partnership arrangements', 'a partnership', 'new partnerships', 'partnership initiatives', 'such partnerships', 'building partnerships', 'partnership building', 'the partnership', 'partnership development', 'collaborative relationships', 'the associations', 'c. partnerships', 'partnership arrangements', 'a partnership', 'new partnerships', 'partnership initiatives', 'such partnerships']
# ===
# Datalogix and Google Partnership
#
#
# Google
# ===
# ['grades awarded', 'the beach grading', 'grade levels', 'the degrees', 'the grade']
# ===
# Strawberry Hill Hotel 4
#
#
# Google
# ===
# ['previous names', 'previous page', 'previous page', 'previous ones', 'the former', 'the name']
# ===
# Backrub
#
#
# Google
# ===
# ['competitive space', 'spatial', 'spatial', 'outer space', 'the spacing', 'place holder ...', 'an area', 'space travel']
# ===
# Online advertising
#
#
# Google
# ===
# ['competitive space', 'spatial', 'spatial', 'outer space', 'the spacing', 'place holder ...', 'an area', 'space travel']
# ===
# Search Advertising
#
#
# Google
# ===
# ['competitive space', 'spatial', 'spatial', 'outer space', 'the spacing', 'place holder ...', 'an area', 'space travel']
# ===
# Google Fiber Internet service provider
#
#
# Google
# ===
# ['competitive space', 'spatial', 'spatial', 'outer space', 'the spacing', 'place holder ...', 'an area', 'space travel']
# ===
# Google Search Information retrieval
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# Google Hacks
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# What Would Google Do?
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# In the Plex
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# I'm Feeling Lucky
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# Is search passé?
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# Leadership agenda 2012
#
#
# Google
# ===
# ['works', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it', 'is working', 'is working', 'public works', "'m working", 'is functioning', "'s working", 'works projects', 'is operating', 'construction work', 'construction works', 'has been working', 'was working', 'does work', "'ve been working", 'working on it']
# ===
# Authors Frequently Mentioned on the Web
